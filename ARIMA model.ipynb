# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 2001-02

# %%
a1 = pd.read_excel('cotton/Book(2001-02).xlsx')

# %%
a1.head()
# Out:
#             State  District    Market Commodity Variety Arrival_Date  \
# 0  Andhra Pradesh  Adilabad  Adilabad    Cotton   Other   21/10/2002
# 1  Andhra Pradesh  Adilabad  Adilabad    Cotton   Other   22/10/2002
# 2  Andhra Pradesh  Adilabad  Adilabad    Cotton   Other   23/10/2002
# 3  Andhra Pradesh  Adilabad  Adilabad    Cotton   Other   24/10/2002
# 4  Andhra Pradesh  Adilabad  Adilabad    Cotton   Other   25/10/2002
#
#    Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price
# 0                0                0             2091.0
# 1                0                0             2061.0
# 2                0                0             2061.0
# 3                0                0             2051.0
# 4                0                0             2051.0

# %%
a2 = (a1['State']=='Gujarat') &(a1['District']=='Amreli')
a3 = a1[a2]
a3 = a3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
a3.shape
# Out:
# (0, 4)

# %% [markdown]
# ## 2003

# %%
c1 = pd.read_excel('cotton/Book(2003).xlsx')

# %%
c2 = (c1['State']=='Gujarat') &(c1['District']=='Amreli')
c3 = c1[c2]

# %%
c3.describe()
# Out:
#        Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price
# count       163.000000       163.000000         163.000000
# mean       2039.239264      2738.435583        1535.196319
# std         300.590177       261.014475        1230.208222
# min         111.000000       220.000000           0.000000
# 25%        1862.500000      2700.000000           0.000000
# 50%        2075.000000      2755.000000        2350.000000
# 75%        2250.000000      2835.000000        2600.000000
# max        2645.000000      3125.000000        2800.000000

# %%
c3 = c3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
c3.shape
# Out:
# (163, 4)

# %% [markdown]
# # 2004

# %%
d1 = pd.read_excel('cotton/Book(2004).xlsx')
d2 = (d1['State']=='Gujarat') &(d1['District']=='Amreli')
d3 = d1[d2]
d3 = d3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
d3.shape
# Out:
# (399, 4)

# %% [markdown]
# # 2005

# %%
e1 = pd.read_excel('cotton/Book(2005).xlsx')
e2 = (e1['State']=='Gujarat') &(e1['District']=='Amreli')
e3 = e1[e2]
e3 = e3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
e3.head()
# Out:
#         State District Arrival_Date  Max_x0020_Price
# 1421  Gujarat   Amreli   01/01/2005           2120.0
# 1422  Gujarat   Amreli   03/01/2005           2080.0
# 1423  Gujarat   Amreli   04/01/2005           2090.0
# 1424  Gujarat   Amreli   05/01/2005           2055.0
# 1425  Gujarat   Amreli   06/01/2005           2120.0

# %%
e3.shape
# Out:
# (511, 4)

# %% [markdown]
# # 2006

# %%
f1 = pd.read_excel('cotton/Book(2006).xlsx')
f2 = (f1['State']=='Gujarat') &(f1['District']=='Amreli')
f3 = f1[f2]
f3 = f3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
f3.head()
# Out:
#         State District Arrival_Date  Max_x0020_Price
# 2744  Gujarat   Amreli   02/01/2006           2540.0
# 2745  Gujarat   Amreli   03/01/2006           2460.0
# 2746  Gujarat   Amreli   04/01/2006           2400.0
# 2747  Gujarat   Amreli   05/01/2006           2500.0
# 2748  Gujarat   Amreli   07/01/2006           2400.0

# %%
f3.shape
# Out:
# (807, 4)

# %% [markdown]
# # 2007

# %%
g1 = pd.read_excel('cotton/Book(2007).xlsx')
g2 = (g1['State']=='Gujarat') &(g1['District']=='Amreli')
g3 = g1[g2]
g3 = g3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
g3.head()
# Out:
#         State District Arrival_Date  Max_x0020_Price
# 2248  Gujarat   Amreli   02/01/2007           2290.0
# 2249  Gujarat   Amreli   03/01/2007           2285.0
# 2250  Gujarat   Amreli   04/01/2007           2275.0
# 2251  Gujarat   Amreli   06/01/2007           2290.0
# 2252  Gujarat   Amreli   08/01/2007           2280.0

# %%
g3.shape
# Out:
# (665, 4)

# %%
#g3.describe()

# %% [markdown]
# # 2008

# %%
h1 = pd.read_excel('cotton/Book(2008).xlsx')
h2 = (h1['State']=='Gujarat') &(h1['District']=='Amreli')
h3 = h1[h2]
h3 = h3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
h3.head()
# Out:
#         State District Arrival_Date  Max_x0020_Price
# 2441  Gujarat   Amreli   01/01/2008           2650.0
# 2442  Gujarat   Amreli   02/01/2008           2695.0
# 2443  Gujarat   Amreli   03/01/2008           2790.0
# 2444  Gujarat   Amreli   04/01/2008           2845.0
# 2445  Gujarat   Amreli   05/01/2008           3000.0

# %%
h3.shape
# Out:
# (1000, 4)

# %% [markdown]
# # 2009

# %%
i1 = pd.read_excel('cotton/Book(2009).xlsx')
i2 = (i1['State']=='Gujarat') &(i1['District']=='Amreli')
i3 = i1[i2]
i3 = i3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
i3.shape
# Out:
# (979, 4)

# %%
i3.describe()
# Out:
#        Max_x0020_Price
# count       979.000000
# mean       2946.668029
# std         213.558383
# min        1755.000000
# 25%        2800.000000
# 50%        2890.000000
# 75%        3100.000000
# max        3755.000000

# %% [markdown]
# # 2010

# %%
j1 = pd.read_excel('cotton/Book(2010).xlsx')
j2 = (j1['State']=='Gujarat') &(j1['District']=='Amreli')
j3 = j1[j2]
j3 = j3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
j3.shape
# Out:
# (1005, 4)

# %% [markdown]
# # 2011

# %%
k1 = pd.read_excel('cotton/Book(2011).xlsx')
k2 = (k1['State']=='Gujarat') &(k1['District']=='Amreli')
k3 = k1[k2]
k3 = k3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
k3.shape
# Out:
# (1135, 4)

# %% [markdown]
# # 2012

# %%
l1 = pd.read_excel('cotton/Book(2012).xlsx')
l2 = (l1['State']=='Gujarat') &(l1['District']=='Amreli')
l3 = l1[l2]
l3 = l3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
l3.shape
# Out:
# (1161, 4)

# %%
#l3.head()

# %% [markdown]
# # 2013

# %%
m1 = pd.read_excel('cotton/Book(2013).xlsx')
m2 = (m1['State']=='Gujarat') &(m1['District']=='Amreli')
m3 = m1[m2]
m3 = m3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
m3.shape
# Out:
# (1132, 4)

# %%
#m3.head()

# %% [markdown]
# # 2014

# %%
n1 = pd.read_excel('cotton/Book(2014).xlsx')
n2 = (n1['State']=='Gujarat') &(n1['District']=='Amreli')
n3 = n1[n2]
n3 = n3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
n3.shape
# Out:
# (1509, 4)

# %% [markdown]
# # 2015

# %%
o1 = pd.read_excel('cotton/Book(2015).xlsx')
o2 = (o1['State']=='Gujarat') &(o1['District']=='Amreli')
o3 = o1[o2]
o3 = o3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
o3.shape
# Out:
# (1170, 4)

# %% [markdown]
# # 2016

# %%
p1 = pd.read_excel('cotton/Book(2016).xlsx')
p2 = (p1['State']=='Gujarat') &(p1['District']=='Amreli')
p3 = p1[p2]
p3 = p3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
#p3.head()

# %%
p3.shape
# Out:
# (973, 4)

# %% [markdown]
# # 2017

# %%
q1 = pd.read_excel('cotton/Book(2017).xlsx')
q2 = (q1['State']=='Gujarat') &(q1['District']=='Amreli')
q3 = q1[q2]
q3 = q3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
q3.shape
# Out:
# (723, 4)

# %% [markdown]
# # 2018

# %%
r1 = pd.read_excel('cotton/Book(2018).xlsx')
r2 = (r1['State']=='Gujarat') &(r1['District']=='Amreli')
r3 = r1[r2]
r3 = r3[['State','District','Arrival_Date','Max_x0020_Price']]

# %%
r3.shape
# Out:
# (1080, 4)

# %% [markdown]
# # 2019

# %%
s1 = pd.read_csv('cotton/Cotton_2019.csv')
s2 = (s1['state']=='Gujarat') &(s1['district']=='Amreli')
s3 = s1[s2]
s3 = s3[['state','district','arrival_date','max_price']]

# %%
s3.shape
# Out:
# (742, 4)

# %%
df1 = pd.concat([a3,c3,d3,e3,f3,g3,h3,i3,j3,k3,l3,m3,n3,o3,p3,q3,r3])

# %%
df1.shape
# Out:
# (14412, 4)

# %%
df1.columns
# Out:
# Index(['State', 'District', 'Arrival_Date', 'Max_x0020_Price'], dtype='object')

# %%
df1.describe()
# Out:
#        Max_x0020_Price
# count     14412.000000
# mean       4166.214474
# std        1255.044095
# min         220.000000
# 25%        3005.000000
# 50%        4370.000000
# 75%        5080.000000
# max        8090.000000

# %%
df4 = df1[['Arrival_Date','Max_x0020_Price']]
#df4.sort_values(by=['Arrival_Date'], inplace=True, ascending=False)

# %%
print(df4)
# Out:
#      Arrival_Date  Max_x0020_Price
# 233    05/04/2003           3030.0
# 234    25/04/2003           2830.0
# 235    28/04/2003           3035.0
# 236    29/04/2003           3100.0
# 237    30/04/2003           3125.0
# ...           ...              ...
# 1983   03/01/2018           5250.0
# 1984   04/01/2018           5245.0
# 1985   05/01/2018           5300.0
# 1986   06/01/2018           5275.0
# 1987   08/01/2018           5325.0
#
# [14412 rows x 2 columns]

# %%
df4['Arrival_Date']=pd.to_datetime(df4['Arrival_Date'])
# Out:
# C:\Users\SAHIL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#df4.to_csv('file2.csv')

# %%
df4 = df4.sort_values(by="Arrival_Date")

# %%
print(df4)
# Out:
#      Arrival_Date  Max_x0020_Price
# 238    2003-01-05           3125.0
# 289    2003-01-10           3095.0
# 354    2003-01-10           2900.0
# 371    2003-01-11           2775.0
# 307    2003-01-11           2820.0
# ...           ...              ...
# 1980   2018-12-28           5555.0
# 1169   2018-12-28           5570.0
# 1170   2018-12-29           5575.0
# 1472   2018-12-29           5515.0
# 1729   2018-12-29           5715.0
#
# [14412 rows x 2 columns]

# %%
df4.to_csv('Amreli.csv')

# %%
df4.set_index('Arrival_Date',inplace=True)

# %%
df4
# Out:
#               Max_x0020_Price
# Arrival_Date
# 2003-01-05             3125.0
# 2003-01-10             3095.0
# 2003-01-10             2900.0
# 2003-01-11             2775.0
# 2003-01-11             2820.0
# ...                       ...
# 2018-12-28             5555.0
# 2018-12-28             5570.0
# 2018-12-29             5575.0
# 2018-12-29             5515.0
# 2018-12-29             5715.0
#
# [14412 rows x 1 columns]

# %%
df4.plot(figsize=(12,8))

# %%
x = df4.rolling(12).mean().plot(label='12 Month Rolling Mean')

# %%
y = df4.rolling(6).mean().plot(label='6 Month Rolling Mean')

# %%
type(x)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
df5 = df4

# %%
df5['6-month-SMA']=df5['Max_x0020_Price'].rolling(window=6).mean()
df5['12-month-SMA']=df5['Max_x0020_Price'].rolling(window=12).mean()

# %%
df5.head()
# Out:
#               Max_x0020_Price  6-month-SMA  12-month-SMA
# Arrival_Date
# 2003-01-11             1980.0          NaN           NaN
# 2003-03-11             2500.0          NaN           NaN
# 2003-03-11             2400.0          NaN           NaN
# 2003-03-11             2600.0          NaN           NaN
# 2003-04-11             2400.0          NaN           NaN

# %%
df5.plot()

# %%
df4['Max_x0020_Price'].plot()
plt.ylabel("Max_Price")
# Out:
# Text(0, 0.5, 'Max_Price')

# %% [markdown]
# # Using Statsmodels to get the trend

# %%
import statsmodels.api as sm

# %%
price_cycle, price_trend = sm.tsa.filters.hpfilter(df5.Max_x0020_Price)

# %%
df5
# Out:
#               Max_x0020_Price  6-month-SMA  12-month-SMA
# Arrival_Date
# 2003-01-11             1980.0          NaN           NaN
# 2003-03-11             2500.0          NaN           NaN
# 2003-03-11             2400.0          NaN           NaN
# 2003-03-11             2600.0          NaN           NaN
# 2003-04-11             2400.0          NaN           NaN
# ...                       ...          ...           ...
# 2015-12-03             4150.0  4150.000000   4150.000000
# 2016-04-24             4500.0  4208.333333   4179.166667
# 2016-04-25             4600.0  4283.333333   4216.666667
# 2016-04-26             4700.0  4375.000000   4262.500000
# 2016-04-28             4600.0  4450.000000   4300.000000
#
# [2611 rows x 3 columns]

# %%
df5["trend"] = price_trend

# %%
df5[['trend','Max_x0020_Price']].plot()

# %%
df5[['Max_x0020_Price','trend']]["2014-03-31":].plot(figsize=(12,8))

# %% [markdown]
# # EWMA
# Exponentially-weighted moving average

# %%
df5['EWMA12'] = df5['Max_x0020_Price'].ewm(span=12).mean()

# %%
df5[['Max_x0020_Price','EWMA12']].plot(figsize=(12,8))

# %%
#type(df5['Max_x0020_Price'])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(df4['Max_x0020_Price'],freq=120, model='multiplicative')
#result.plot()

# %%
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(15, 8)

# %% [markdown]
# # Testing for Stationarity

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result1 = adfuller(df4['Max_x0020_Price'])

# %%
print('Augmented Dickey-Fuller Test:')
labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']

for value,label in zip(result1,labels):
    print(label+' : '+str(value) )
    
if result1[1] <= 0.05:
    print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
else:
    print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -0.8396477659768126
# p-value : 0.8071975982894419
# #Lags Used : 21
# Number of Observations Used : 2589
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
# Store in a function for later use!
def adf_check(time_series):
    """
    Pass in a time series, returns ADF report
    """
    result1 = adfuller(time_series)
    print('Augmented Dickey-Fuller Test:')
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']

    for value,label in zip(result1,labels):
        print(label+' : '+str(value) )
    
    if result1[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %% [markdown]
# # Differencing

# %%
df7 = df4

# %%
#df6

# %%
df6['first_diff'] = df6['Max_x0020_Price'] - df6['Max_x0020_Price'].shift(1)

# %%
adf_check(df6['first_diff'].dropna())
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -21.909807323938047
# p-value : 0.0
# #Lags Used : 28
# Number of Observations Used : 2580
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
df6['first_diff'].plot(figsize=(12,8))

# %%
df7['sec_diff'] = df7['first_diff'] - df7['first_diff'].shift(1)

# %%
adf_check(df7['sec_diff'].dropna())
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -23.92697535373537
# p-value : 0.0
# #Lags Used : 28
# Number of Observations Used : 2579
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
df7['sec_diff'].plot(figsize=(12,8))

# %%
df7['Seasonal Difference'] = df7['Max_x0020_Price'] - df7['Max_x0020_Price'].shift(12)
df7['Seasonal Difference'].plot(figsize=(12,8))

# %%
adf_check(df7['Seasonal Difference'].dropna())
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -16.723103274688835
# p-value : 1.4031963200860407e-29
# #Lags Used : 27
# Number of Observations Used : 2570
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
# You can also do seasonal first difference
df7['Seasonal First Difference'] = df7['Seasonal Difference'] - df7['Seasonal Difference'].shift(12)
df7['Seasonal First Difference'].plot()

# %%
adf_check(df7['Seasonal First Difference'].dropna())
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -20.462277366345706
# p-value : 0.0
# #Lags Used : 27
# Number of Observations Used : 2558
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig_first = plot_acf(df7["Seasonal Difference"].dropna())

# %%
result2 = plot_pacf(df7["Seasonal First Difference"].dropna())

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
df10 = pd.concat([a3,c3,d3,e3,f3,g3,h3,i3,j3,k3,l3,m3,n3,o3,p3,q3,r3])

# %%
df11 = df10[['Arrival_Date','Max_x0020_Price']]
df11['Arrival_Date']=pd.to_datetime(df11['Arrival_Date'])
df11 = df11.sort_values(by="Arrival_Date")
df11.set_index("Arrival_Date",inplace=True)
# Out:
# C:\Users\SAHIL\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df11
# Out:
#               Max_x0020_Price
# Arrival_Date
# 2003-01-11             1980.0
# 2003-03-11             2500.0
# 2003-03-11             2400.0
# 2003-03-11             2600.0
# 2003-04-11             2400.0
# ...                       ...
# 2015-12-03             4150.0
# 2016-04-24             4500.0
# 2016-04-25             4600.0
# 2016-04-26             4700.0
# 2016-04-28             4600.0
#
# [2611 rows x 1 columns]

# %%
model = sm.tsa.statespace.SARIMAX(df11['Max_x0020_Price'],order=(0,1,0), seasonal_order=(1,1,1,12))
results23 = model.fit()
print(results23.summary())
# Out:
# C:\Users\SAHIL\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                                  Statespace Model Results
# ...
# Dep. Variable:                    Max_x0020_Price   No. Observations:                 2611
# Model:             SARIMAX(0, 1, 0)x(1, 1, 1, 12)   Log Likelihood              -18498.127
# Date:                            Tue, 14 Jan 2020   AIC                          37002.254
# Time:                                    14:24:53   BIC                          37019.841
# Sample:                                         0   HQIC                         37008.627
#                                            - 2611
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
results23.resid.plot(figsize=(12,8))

# %%
results23.resid.plot(kind='kde')
